# %% [markdown]
# <a href="https://colab.research.google.com/github/AndreHidayatullah/DAA/blob/main/DAA11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# a-----b
# /     /
# /     /
# C-----d-----e

# %%
# Create the dictionary with graph elements
graph = {"a" : ["b","c"],
         "b" : ["a","d"],
         "c" : ["a","d"],
         "d" : ["e"],
         "e" : ["d"]
         }
# Print the graph
print(graph)
# Out:
# {'a': ['b', 'c'], 'b': ['a', 'd'], 'c': ['a', 'd'], 'd': ['e'], 'e': ['d']}

# %%
# Latihan Halaman 29

# T ----- U ----- V
# |               |
# W ------------- X
# |               |
# Z               S

graph_TUV = {
    "T": ["U","W"],
    "U": ["T","V"],
    "V": ["U","X"],
    "W": ["T","X","Z"],
    "X": ["V","W","S"],
    "Z": ["W"],
    "S": ["X"]
}

print(graph_TUV)
# Out:
# {'T': ['U', 'W'], 'U': ['T', 'V'], 'V': ['U', 'X'], 'W': ['T', 'X', 'Z'], 'X': ['V', 'W', 'S'], 'Z': ['W'], 'S': ['X']}

# %%
# Latihan Halaman 30

# r ----- o ------ m
# |       |        |
# l ----- p ------ n

graph_ROM = {
    "r": ["o","l"],
    "o": ["r","p","m"],
    "m": ["o","n"],
    "l": ["r","p"],
    "p": ["l","o","n"],
    "n": ["p","m"]
}

print(graph_ROM)
# Out:
# {'r': ['o', 'l'], 'o': ['r', 'p', 'm'], 'm': ['o', 'n'], 'l': ['r', 'p'], 'p': ['l', 'o', 'n'], 'n': ['p', 'm']}

# %%
class Graph:
    def __init__(self,gdict=None):
        if gdict is None:
            gdict = []
        self.gdict = gdict

    def getVertices(self):
        return list(self.gdict.keys())
# Create dictionary with graph elements
graph_elements = {
         "a" : ["b","c"],
         "b" : ["a","d"],
         "c" : ["a","d"],
         "d" : ["e"],
         "e" : ["d"]
         }

# Create an instance of the graph class and pass the graph_elements
g = Graph(graph_elements)

# Print the vertices by calling the getVertices method with parentheses
print(g.getVertices())
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
# Latihan Halaman 32

class Graph:
    def __init__(self, gdict=None):
        if gdict is None:
            gdict = {}
        self.gdict = gdict

    def getVertices(self):
        return list(self.gdict.keys())

g = Graph(graph_TUV)
print("Vertices TUV:", g.getVertices())
# Out:
# Vertices TUV: ['T', 'U', 'V', 'W', 'X', 'Z', 'S']

# %%
# Latihan Halaman 33

g = Graph(graph_ROM)
print("Vertices ROM:", g.getVertices())
# Out:
# Vertices ROM: ['r', 'o', 'm', 'l', 'p', 'n']

# %%
class graph:
    def __init__(self,gdict=None):
        if gdict is None:
            gdict = {}
        self.gdict = gdict

    def edges(self):
        return self.findedges()

# Find the distinct list of edges
    def findedges(self):
        edgename = []
        for vrtx in self.gdict:
            for nxtvrtx in self.gdict[vrtx]:
                if {nxtvrtx, vrtx} not in edgename:
                    edgename.append({vrtx, nxtvrtx})
        return edgename

# Create the disctionary with graph elements
graph_elements = { "a" : ["b","c"],
         "b" : ["a","d"],
         "c" : ["a","d"],
         "d" : ["e"],
         "e" : ["d"]
         }

g = graph(graph_elements)

print(g.edges())
# Out:
# [{'a', 'b'}, {'a', 'c'}, {'d', 'b'}, {'c', 'd'}, {'e', 'd'}]

# %%
# Latihan Halaman 35

class graph:
    def __init__(self, gdict=None):
        if gdict is None:
            gdict = {}
        self.gdict = gdict

    def edges(self):
        edgename = []
        for v in self.gdict:
            for n in self.gdict[v]:
                if {v, n} not in edgename:
                    edgename.append({v, n})
        return edgename

g = graph(graph_TUV)
print("Edges TUV:", g.edges())
# Out:
# Edges TUV: [{'T', 'U'}, {'W', 'T'}, {'V', 'U'}, {'V', 'X'}, {'W', 'X'}, {'W', 'Z'}, {'S', 'X'}]

# %%
# Latihan Halaman 36

g = graph(graph_ROM)
print("Edges ROM:", g.edges())
# Out:
# Edges ROM: [{'o', 'r'}, {'l', 'r'}, {'o', 'p'}, {'o', 'm'}, {'m', 'n'}, {'p', 'l'}, {'p', 'n'}]

# %%
class graph:
    def __init__(self,gdict=None):
        if gdict is None:
            gdict = {}
        self.gdict = gdict

    def getVertices(self):
        return list(self.gdict.keys())

# Add the vertex as a key
    def addVertex(self, vrtx):
        if vrtx not in self.gdict:
            self.gdict[vrtx] = []

# Create the dictionary with graph elements
graph_elements = { "a" : ["b","c"],
         "b" : ["a","d"],
         "c" : ["a","d"],
         "d" : ["e"],
         "e" : ["d"]
         }

g = graph(graph_elements)

g.addVertex("f")

print(g.getVertices())
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f']

# %%
# Latihan Halaman 38

class graph2:
    def __init__(self, gdict=None):
        if gdict is None:
            gdict = {}
        self.gdict = gdict

    def addVertex(self, v):
        if v not in self.gdict:
            self.gdict[v] = []

g = graph2(graph_TUV)
g.addVertex("R")
print("Vertices TUV setelah tambah R:", g.gdict)
# Out:
# Vertices TUV setelah tambah R: {'T': ['U', 'W'], 'U': ['T', 'V'], 'V': ['U', 'X'], 'W': ['T', 'X', 'Z'], 'X': ['V', 'W', 'S'], 'Z': ['W'], 'S': ['X'], 'R': []}

# %%
# Latihan Halaman 39

g = graph2(graph_ROM)
g.addVertex("K")
g.addVertex("J")

print("Vertices ROM setelah tambah K dan J:", g.gdict)
# Out:
# Vertices ROM setelah tambah K dan J: {'r': ['o', 'l'], 'o': ['r', 'p', 'm'], 'm': ['o', 'n'], 'l': ['r', 'p'], 'p': ['l', 'o', 'n'], 'n': ['p', 'm'], 'K': [], 'J': []}

# %%
class graph:
    def __init__(self,gdict=None):
        if gdict is None:
            gdict = {}
        self.gdict = gdict

    def edges(self):
        return self.findedges()

# Add the new edge

    def AddEdge(self, edge):
        edge = set(edge)
        (vrtx1, vrtx2) = tuple(edge)
        if vrtx1 in self.gdict:
            self.gdict[vrtx1].append(vrtx2)
        else:
            self.gdict[vrtx1] = [vrtx2]

# List the edge names
    def findedges(self):
        edgename = []
        for vrtx in self.gdict:
            for nxtvrtx in self.gdict[vrtx]:
                if {nxtvrtx, vrtx} not in edgename:
                    edgename.append({vrtx, nxtvrtx})
        return edgename

# %%
# Create the dictionary with graph elements
graph_elements = { "a" : ["b","c"],
         "b" : ["a","d"],
         "c" : ["a","d"],
         "d" : ["e"],
         "e" : ["d"]
         }

g = graph(graph_elements)
g.AddEdge({'a','e'})
g.AddEdge({'a','c'})
print(g.edges())
# Out:
# [{'a', 'b'}, {'a', 'c'}, {'d', 'b'}, {'c', 'd'}, {'e', 'd'}, {'e', 'a'}]

# %%
# Latihan Halaman 42

class graph3:
    def __init__(self, gdict=None):
        if gdict is None:
            gdict = {}
        self.gdict = gdict

    def AddEdge(self, edge):
        edge = set(edge)
        (v1, v2) = tuple(edge)
        if v1 in self.gdict:
            self.gdict[v1].append(v2)
        else:
            self.gdict[v1] = [v2]

g = graph3(graph_TUV)
g.AddEdge({"T","Z"})
g.AddEdge({"V","S"})

print("Edges TUV setelah penambahan:", g.gdict)
# Out:
# Edges TUV setelah penambahan: {'T': ['U', 'W'], 'U': ['T', 'V'], 'V': ['U', 'X'], 'W': ['T', 'X', 'Z'], 'X': ['V', 'W', 'S'], 'Z': ['W', 'T'], 'S': ['X', 'V'], 'R': []}

# %%
# Latihan Halaman 43

g = graph3(graph_ROM)

# tambah vertex dulu jika belum ada
if "K" not in g.gdict: g.gdict["K"] = []
if "J" not in g.gdict: g.gdict["J"] = []
if "R" not in g.gdict: g.gdict["R"] = []

# tambahkan edge
g.AddEdge({"R","K"})
g.AddEdge({"M","J"})

print("Edges ROM setelah penambahan:", g.gdict)
# Out:
# Edges ROM setelah penambahan: {'r': ['o', 'l'], 'o': ['r', 'p', 'm'], 'm': ['o', 'n'], 'l': ['r', 'p'], 'p': ['l', 'o', 'n'], 'n': ['p', 'm'], 'K': ['R'], 'J': [], 'R': [], 'M': ['J']}
